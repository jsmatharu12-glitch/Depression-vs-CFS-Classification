# %%
import pandas 
import numpy
import streamlit as st 
import pickle
import sklearn

lr = pickle.load(open('lr1'.'pkl.'rb))
df = pickle.load(open('df1'.'pkl.'rb))
rf = pickle.load(open('rf1'.'pkl.'rb))

model = st.sidebar.selectbox('select the ML Model')


if model = "LogReg":
    pred = lr.predict(text_df)
elif model == "Decision Tree":
    pred = dt.predict(text_df)
    st.success(pred[0])
else:
    pred = rf.predict(text_df)
    st.success(pred[0])
